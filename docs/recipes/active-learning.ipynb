# %% [markdown]
# # Active learning

# %%
import inspect
from river import conf
from river import datasets
from river import linear_model
from river import metrics
from river import preprocessing
from river import stats

dataset = datasets.TrumpApproval()

model = conf.RegressionJackknife(
    (
        preprocessing.StandardScaler() |
        linear_model.LinearRegression(intercept_lr=.1)
    ),
    confidence_level=0.9
)

inspect.signature(model.learn_one)
# Out:
# <Signature (x, y)>

# %%
arg_info = inspect.getfullargspec(model.learn_one)
arg_info
# Out:
# FullArgSpec(args=['self', 'x', 'y'], varargs=None, varkw=None, defaults=None, kwonlyargs=[], kwonlydefaults=None, annotations={})

# %%
from river import datasets
from river import evaluate
from river import imblearn
from river import metrics
from river import preprocessing
from river import rules

model = (
    preprocessing.StandardScaler() |
    imblearn.ChebyshevUnderSampler(
        regressor=rules.AMRules(
            n_min=50, delta=0.01,
        ),
        seed=42
    )
)
inspect.signature(model.learn_one)
# Out:
# <Signature (x: 'dict', y=None, **params)>

# %%
arg_info = inspect.getfullargspec(model.learn_one)
arg_info
# Out:
# FullArgSpec(args=['self', 'x', 'y'], varargs=None, varkw='params', defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={'x': 'dict'})

# %% [markdown]
# ## Online active learning

# %%
from river import datasets

dataset = datasets.SMSSpam()
for x, y in dataset:
    print(x)
# Out:
# Downloading https://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip (198.65 KB)
# Uncompressing into /Users/max/river_data/SMSSpam
# {'body': 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...\n'}
# {'body': 'Ok lar... Joking wif u oni...\n'}
# {'body': "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's\n"}
# {'body': 'U dun say so early hor... U c already then say...\n'}
# {'body': "Nah I don't think he goes to usf, he lives around here though\n"}
# {'body': "FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, £1.50 to rcv\n"}
# {'body': 'Even my brother is not like to speak with me. They treat me like aids patent.\n'}
# {'body': "As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune\n"}
# {'body': 'WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.\n'}
# {'body': 'Had your mobile 11 months or more? U R entitled to Update to the latest colour mobiles with camera for Free! Call The Mobile Update Co FREE on 08002986030\n'}
# {'body': "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.\n"}
# {'body': 'SIX chances to win CASH! From 100 to 20,000 pounds txt> CSH11 and send to 87575. Cost 150p/day, 6days, 16+ TsandCs apply Reply HL 4 info\n'}
# {'body': 'URGENT! You have won a 1 week FREE membership in our £100,000 Prize Jackpot! Txt the word: CLAIM to No: 81010 T&C www.dbuk.net LCCLTD POBOX 4403LDNW1A7RW18\n'}
# {'body': "I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times.\n"}
# {'body': 'I HAVE A DATE ON SUNDAY WITH WILL!!\n'}
# {'body': 'XXXMobileMovieClub: To use your credit, click the WAP link in the next txt message or click here>> http://wap. xxxmobilemovieclub.com?n=QJKGIGHJJGCBL\n'}
# {'body': "Oh k...i'm watching here:)\n"}
# {'body': 'Eh u remember how 2 spell his name... Yes i did. He v naughty make until i v wet.\n'}
# {'body': 'Fine if that\x92s the way u feel. That\x92s the way its gota b\n'}
# {'body': 'England v Macedonia - dont miss the goals/team news. Txt ur national team to 87077 eg ENGLAND to 87077 Try:WALES, SCOTLAND 4txt/ú1.20 POBOXox36504W45WQ 16+\n'}
# {'body': 'Is that seriously how you spell his name?\n'}
# {'body': 'I‘m going to try for 2 months ha ha only joking\n'}
# {'body': 'So ü pay first lar... Then when is da stock comin...\n'}
# {'body': 'Aft i finish my lunch then i go str down lor. Ard 3 smth lor. U finish ur lunch already?\n'}
# {'body': 'Ffffffffff. Alright no way I can meet up with you sooner?\n'}
# {'body': "Just forced myself to eat a slice. I'm really not hungry tho. This sucks. Mark is getting worried. He knows I'm sick when I turn down pizza. Lol\n"}
# {'body': 'Lol your always so convincing.\n'}
# {'body': "Did you catch the bus ? Are you frying an egg ? Did you make a tea? Are you eating your mom's left over dinner ? Do you feel my Love ?\n"}
# {'body': "I'm back &amp; we're packing the car now, I'll let you know if there's room\n"}
# {'body': 'Ahhh. Work. I vaguely remember that! What does it feel like? Lol\n'}
# {'body': "Wait that's still not all that clear, were you not sure about me being sarcastic or that that's why x doesn't want to live with us\n"}
# {'body': "Yeah he got in at 2 and was v apologetic. n had fallen out and she was actin like spoilt child and he got caught up in that. Till 2! But we won't go there! Not doing too badly cheers. You? \n"}
# {'body': 'K tell me anything about you.\n'}
# {'body': 'For fear of fainting with the of all that housework you just did? Quick have a cuppa\n'}
# {'body': 'Thanks for your subscription to Ringtone UK your mobile will be charged £5/month Please confirm by replying YES or NO. If you reply NO you will not be charged\n'}
# {'body': 'Yup... Ok i go home look at the timings then i msg ü again... Xuhui going to learn on 2nd may too but her lesson is at 8am\n'}
# {'body': "Oops, I'll let you know when my roommate's done\n"}
# {'body': 'I see the letter B on my car\n'}
# {'body': 'Anything lor... U decide...\n'}
# {'body': "Hello! How's you and how did saturday go? I was just texting to see if you'd decided to do anything tomo. Not that i'm trying to invite myself or anything!\n"}
# {'body': 'Pls go ahead with watts. I just wanted to be sure. Do have a great weekend. Abiola\n'}
# {'body': 'Did I forget to tell you ? I want you , I need you, I crave you ... But most of all ... I love you my sweet Arabian steed ... Mmmmmm ... Yummy\n'}
# {'body': '07732584351 - Rodger Burns - MSG = We tried to call you re your reply to our sms for a free nokia mobile + free camcorder. Please call now 08000930705 for delivery tomorrow\n'}
# {'body': 'WHO ARE YOU SEEING?\n'}
# {'body': 'Great! I hope you like your man well endowed. I am  &lt;#&gt;  inches...\n'}
# {'body': 'No calls..messages..missed calls\n'}
# {'body': "Didn't you get hep b immunisation in nigeria.\n"}
# {'body': 'Fair enough, anything going on?\n'}
# {'body': "Yeah hopefully, if tyler can't do it I could maybe ask around a bit\n"}
# {'body': "U don't know how stubborn I am. I didn't even want to go to the hospital. I kept telling Mark I'm not a weak sucker. Hospitals are for weak suckers.\n"}
# {'body': 'What you thinked about me. First time you saw me in class.\n'}
# {'body': 'A gram usually runs like  &lt;#&gt; , a half eighth is smarter though and gets you almost a whole second gram for  &lt;#&gt;\n'}
# {'body': "K fyi x has a ride early tomorrow morning but he's crashing at our place tonight\n"}
# {'body': 'Wow. I never realized that you were so embarassed by your accomodations. I thought you liked it, since i was doing the best i could and you always seemed so happy about "the cave". I\'m sorry I didn\'t and don\'t have more to give. I\'m sorry i offered. I\'m sorry your room was so embarassing.\n'}
# {'body': 'SMS. ac Sptv: The New Jersey Devils and the Detroit Red Wings play Ice Hockey. Correct or Incorrect? End? Reply END SPTV\n'}
# {'body': 'Do you know what Mallika Sherawat did yesterday? Find out now @  &lt;URL&gt;\n'}
# {'body': 'Congrats! 1 year special cinema pass for 2 is yours. call 09061209465 now! C Suprman V, Matrix3, StarWars3, etc all 4 FREE! bx420-ip4-5we. 150pm. Dont miss out! \n'}
# {'body': "Sorry, I'll call later in meeting.\n"}
# {'body': 'Tell where you reached\n'}
# {'body': 'Yes..gauti and sehwag out of odi series.\n'}
# {'body': "Your gonna have to pick up a $1 burger for yourself on your way home. I can't even move. Pain is killing me.\n"}
# {'body': 'Ha ha ha good joke. Girls are situation seekers.\n'}
# {'body': 'Its a part of checking IQ\n'}
# {'body': 'Sorry my roommates took forever, it ok if I come by now?\n'}
# {'body': 'Ok lar i double check wif da hair dresser already he said wun cut v short. He said will cut until i look nice.\n'}
# {'body': 'As a valued customer, I am pleased to advise you that following recent review of your Mob No. you are awarded with a £1500 Bonus Prize, call 09066364589\n'}
# {'body': 'Today is "song dedicated day.." Which song will u dedicate for me? Send this to all ur valuable frnds but first rply me...\n'}
# {'body': 'Urgent UR awarded a complimentary trip to EuroDisinc Trav, Aco&Entry41 Or £1000. To claim txt DIS to 87121 18+6*£1.50(moreFrmMob. ShrAcomOrSglSuplt)10, LS1 3AJ\n'}
# {'body': 'Did you hear about the new "Divorce Barbie"? It comes with all of Ken\'s stuff!\n'}
# {'body': 'I plane to give on this month end.\n'}
# {'body': 'Wah lucky man... Then can save money... Hee...\n'}
# {'body': 'Finished class where are you.\n'}
# {'body': 'HI BABE IM AT HOME NOW WANNA DO SOMETHING? XX\n'}
# {'body': 'K..k:)where are you?how did you performed?\n'}
# {'body': 'U can call me now...\n'}
# {'body': 'I am waiting machan. Call me once you free.\n'}
# {'body': 'Thats cool. i am a gentleman and will treat you with dignity and respect.\n'}
# {'body': 'I like you peoples very much:) but am very shy pa.\n'}
# {'body': 'Does not operate after  &lt;#&gt;  or what\n'}
# {'body': "Its not the same here. Still looking for a job. How much do Ta's earn there.\n"}
# {'body': "Sorry, I'll call later\n"}
# {'body': 'K. Did you call me just now ah? \n'}
# {'body': 'Ok i am on the way to home hi hi\n'}
# {'body': 'You will be in the place of that man\n'}
# {'body': 'Yup next stop.\n'}
# {'body': "I call you later, don't have network. If urgnt, sms me.\n"}
# {'body': "For real when u getting on yo? I only need 2 more tickets and one more jacket and I'm done. I already used all my multis.\n"}
# {'body': "Yes I started to send requests to make it but pain came back so I'm back in bed. Double coins at the factory too. I gotta cash in all my nitros.\n"}
# {'body': "I'm really not up to it still tonight babe\n"}
# {'body': 'Ela kano.,il download, come wen ur free..\n'}
# {'body': 'Yeah do! Don‘t stand to close tho- you‘ll catch something!\n'}
# {'body': "Sorry to be a pain. Is it ok if we meet another night? I spent late afternoon in casualty and that means i haven't done any of y stuff42moro and that includes all my time sheets and that. Sorry. \n"}
# {'body': 'Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile when sum1 Hurts U Smile becoz SOMEONE still Loves to see u Smiling!!\n'}
# {'body': 'Please call our customer service representative on 0800 169 6031 between 10am-9pm as you have WON a guaranteed £1000 cash or £5000 prize!\n'}
# {'body': 'Havent planning to buy later. I check already lido only got 530 show in e afternoon. U finish work already?\n'}
# {'body': 'Your free ringtone is waiting to be collected. Simply text the password "MIX" to 85069 to verify. Get Usher and Britney. FML, PO Box 5249, MK17 92H. 450Ppw 16\n'}
# {'body': 'Watching telugu movie..wat abt u?\n'}
# {'body': 'i see. When we finish we have loads of loans to pay\n'}
# {'body': 'Hi. Wk been ok - on hols now! Yes on for a bit of a run. Forgot that i have hairdressers appointment at four so need to get home n shower beforehand. Does that cause prob for u?"\n'}
# {'body': 'I see a cup of coffee animation\n'}
# {'body': "Please don't text me anymore. I have nothing else to say.\n"}
# {'body': 'Okay name ur price as long as its legal! Wen can I pick them up? Y u ave x ams xx\n'}
# {'body': "I'm still looking for a car to buy. And have not gone 4the driving test yet.\n"}
# {'body': "As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune\n"}
# {'body': "wow. You're right! I didn't mean to do that. I guess once i gave up on boston men and changed my search location to nyc, something changed. Cuz on my signin page it still says boston.\n"}
# {'body': 'Umma my life and vava umma love you lot dear\n'}
# {'body': 'Thanks a lot for your wishes on my birthday. Thanks you for making my birthday truly memorable.\n'}
# {'body': "Aight, I'll hit you up when I get some cash\n"}
# {'body': "How would my ip address test that considering my computer isn't a minecraft server\n"}
# {'body': 'I know! Grumpy old people. My mom was like you better not be lying. Then again I am always the one to play jokes...\n'}
# {'body': "Dont worry. I guess he's busy.\n"}
# {'body': 'What is the plural of the noun research?\n'}
# {'body': 'Going for dinner.msg you after.\n'}
# {'body': "I'm ok wif it cos i like 2 try new things. But i scared u dun like mah. Cos u said not too loud.\n"}
# {'body': 'GENT! We are trying to contact you. Last weekends draw shows that you won a £1000 prize GUARANTEED. Call 09064012160. Claim Code K52. Valid 12hrs only. 150ppm\n'}
# {'body': "Wa, ur openin sentence very formal... Anyway, i'm fine too, juz tt i'm eatin too much n puttin on weight...Haha... So anythin special happened?\n"}
# {'body': "As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there.\n"}
# {'body': 'You are a winner U have been specially selected 2 receive £1000 or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810910p/min (18+) \n'}
# {'body': 'Goodo! Yes we must speak friday - egg-potato ratio for tortilla needed! \n'}
# {'body': "Hmm...my uncle just informed me that he's paying the school directly. So pls buy food.\n"}
# {'body': 'PRIVATE! Your 2004 Account Statement for 07742676969 shows 786 unredeemed Bonus Points. To claim call 08719180248 Identifier Code: 45239 Expires\n'}
# {'body': 'URGENT! Your Mobile No. was awarded £2000 Bonus Caller Prize on 5/9/03 This is our final try to contact U! Call from Landline 09064019788 BOX42WR29C, 150PPM\n'}
# {'body': 'here is my new address -apples&pairs&all that malarky\n'}
# {'body': 'Todays Voda numbers ending 7548 are selected to receive a $350 award. If you have a match please call 08712300220 quoting claim code 4041 standard rates app\n'}
# {'body': 'I am going to sao mu today. Will be done only at 12 \n'}
# {'body': "Ü predict wat time ü'll finish buying?\n"}
# {'body': 'Good stuff, will do.\n'}
# {'body': "Just so that you know,yetunde hasn't sent money yet. I just sent her a text not to bother sending. So its over, you dont have to involve yourself in anything. I shouldn't have imposed anything on you in the first place so for that, i apologise.\n"}
# {'body': 'Are you there in room.\n'}
# {'body': 'HEY GIRL. HOW R U? HOPE U R WELL ME AN DEL R BAK! AGAIN LONG TIME NO C! GIVE ME A CALL SUM TIME FROM LUCYxx\n'}
# {'body': 'K..k:)how much does it cost?\n'}
# {'body': "I'm home.\n"}
# {'body': 'Dear, will call Tmorrow.pls accomodate.\n'}
# {'body': 'First answer my question.\n'}
# {'body': 'Sunshine Quiz Wkly Q! Win a top Sony DVD player if u know which country the Algarve is in? Txt ansr to 82277. £1.50 SP:Tyrone\n'}
# {'body': "Want 2 get laid tonight? Want real Dogging locations sent direct 2 ur mob? Join the UK's largest Dogging Network bt Txting GRAVEL to 69888! Nt. ec2a. 31p.msg@150p\n"}
# {'body': "I only haf msn. It's yijue@hotmail.com\n"}
# {'body': 'He is there. You call and meet him\n'}
# {'body': 'No no. I will check all rooms befor activities\n'}
# {'body': "You'll not rcv any more msgs from the chat svc. For FREE Hardcore services text GO to: 69988 If u get nothing u must Age Verify with yr network & try again\n"}
# {'body': 'Got c... I lazy to type... I forgot ü in lect... I saw a pouch but like not v nice...\n'}
# {'body': "K, text me when you're on the way\n"}
# {'body': 'Sir, Waiting for your mail.\n'}
# {'body': 'A swt thought: "Nver get tired of doing little things 4 lovable persons.." Coz..somtimes those little things occupy d biggest part in their Hearts.. Gud ni8\n'}
# {'body': 'I know you are. Can you pls open the back?\n'}
# {'body': 'Yes see ya not on the dot\n'}
# {'body': 'Whats the staff name who is taking class for us?\n'}
# {'body': "FreeMsg Why haven't you replied to my text? I'm Randy, sexy, female and live local. Luv to hear from u. Netcollex Ltd 08700621170150p per msg reply Stop to end\n"}
# {'body': 'Ummma.will call after check in.our life will begin from qatar so pls pray very hard.\n'}
# {'body': 'K..i deleted my contact that why?\n'}
# {'body': 'Sindu got job in birla soft ..\n'}
# {'body': "The wine is flowing and i'm i have nevering..\n"}
# {'body': 'Yup i thk cine is better cos no need 2 go down 2 plaza mah.\n'}
# {'body': 'Ok... Ur typical reply...\n'}
# {'body': "As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune\n"}
# {'body': 'You are everywhere dirt, on the floor, the windows, even on my shirt. And sometimes when i open my mouth, you are all that comes flowing out. I dream of my world without you, then half my chores are out too. A time of joy for me, lots of tv shows i.ll see. But i guess like all things you just must exist, like rain, hail and mist, and when my time here is done, you and i become one.\n'}
# {'body': 'Aaooooright are you at work?\n'}
# {'body': "I'm leaving my house now...\n"}
# {'body': 'Hello, my love. What are you doing? Did you get to that interview today? Are you you happy? Are you being a good boy? Do you think of me?Are you missing me ?\n'}
# {'body': 'Customer service annoncement. You have a New Years delivery waiting for you. Please call 07046744435 now to arrange delivery\n'}
# {'body': 'You are a winner U have been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810810\n'}
# {'body': "Keep yourself safe for me because I need you and I miss you already and I envy everyone that see's you in real life\n"}
# {'body': 'New car and house for my parents.:)i have only new job in hand:)\n'}
# {'body': "I'm so in love with you. I'm excited each day i spend with you. You make me so happy.\n"}
# {'body': '-PLS STOP bootydelious (32/F) is inviting you to be her friend. Reply YES-434 or NO-434 See her: www.SMS.ac/u/bootydelious STOP? Send STOP FRND to 62468\n'}
# {'body': 'BangBabes Ur order is on the way. U SHOULD receive a Service Msg 2 download UR content. If U do not, GoTo wap. bangb. tv on UR mobile internet/service menu\n'}
# {'body': 'I place all ur points on e cultures module already.\n'}
# {'body': 'URGENT! We are trying to contact you. Last weekends draw shows that you have won a £900 prize GUARANTEED. Call 09061701939. Claim code S89. Valid 12hrs only\n'}
# {'body': "Hi frnd, which is best way to avoid missunderstding wit our beloved one's?\n"}
# {'body': 'Great escape. I fancy the bridge but needs her lager. See you tomo \n'}
# {'body': 'Yes :)it completely in out of form:)clark also utter waste.\n'}
# {'body': 'Sir, I need AXIS BANK account no and bank address.\n'}
# {'body': 'Hmmm.. Thk sure got time to hop ard... Ya, can go 4 free abt... Muz call u to discuss liao... \n'}
# {'body': 'What time you coming down later? \n'}
# {'body': 'Bloody hell, cant believe you forgot my surname Mr . Ill give u a clue, its spanish and begins with m... \n'}
# {'body': "Well, i'm gonna finish my bath now. Have a good...fine night.\n"}
# {'body': "Let me know when you've got the money so carlos can make the call\n"}
# {'body': 'U still going to the mall?\n'}
# {'body': "Turns out my friends are staying for the whole show and won't be back til ~ &lt;#&gt; , so feel free to go ahead and smoke that $ &lt;#&gt;  worth\n"}
# {'body': 'Text her. If she doesnt reply let me know so i can have her log in\n'}
# {'body': "Hi! You just spoke to MANEESHA V. We'd like to know if you were satisfied with the experience. Reply Toll Free with Yes or No.\n"}
# {'body': 'You lifted my hopes with the offer of money. I am in need. Especially when the end of the month approaches and it hurts my studying. Anyways have a gr8 weekend\n'}
# {'body': 'Lol no. U can trust me.\n'}
# {'body': 'ok. I am a gentleman and will treat you with dignity and respect.\n'}
# {'body': 'He will, you guys close?\n'}
# {'body': 'Going on nothing great.bye\n'}
# {'body': "Hello handsome ! Are you finding that job ? Not being lazy ? Working towards getting back that net for mummy ? Where's my boytoy now ? Does he miss me ?\n"}
# {'body': 'Haha awesome, be there in a minute\n'}
# {'body': 'Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed £1000 cash or £5000 prize!\n'}
# {'body': 'Have you got Xmas radio times. If not i will get it now\n'}
# {'body': 'I jus reached home. I go bathe first. But my sis using net tell u when she finishes k...\n'}
# {'body': 'Are you unique enough? Find out from 30th August. www.areyouunique.co.uk\n'}
# {'body': "I'm sorry. I've joined the league of people that dont keep in touch. You mean a great deal to me. You have been a friend at all times even at great personal cost. Do have a great week.|\n"}
# {'body': 'Hi :)finally i completed the course:)\n'}
# {'body': 'It will stop on itself. I however suggest she stays with someone that will be able to give ors for every stool.\n'}
# {'body': "How are you doing? Hope you've settled in for the new school year. Just wishin you a gr8 day\n"}
# {'body': 'Gud mrng dear hav a nice day\n'}
# {'body': 'Did u got that persons story\n'}
# {'body': 'is your hamster dead? Hey so tmr i meet you at 1pm orchard mrt? \n'}
# {'body': 'Hi its Kate how is your evening? I hope i can see you tomorrow for a bit but i have to bloody babyjontet! Txt back if u can. :) xxx\n'}
# {'body': 'Found it, ENC  &lt;#&gt; , where you at?\n'}
# {'body': 'I sent you  &lt;#&gt;  bucks\n'}
# {'body': 'Hello darlin ive finished college now so txt me when u finish if u can love Kate xxx\n'}
# {'body': 'Your account has been refilled successfully by INR  &lt;DECIMAL&gt; . Your KeralaCircle prepaid account balance is Rs  &lt;DECIMAL&gt; . Your Transaction ID is KR &lt;#&gt; .\n'}
# {'body': 'Goodmorning sleeping ga.\n'}
# {'body': 'U call me alter at 11 ok.\n'}
# {'body': 'Ü say until like dat i dun buy ericsson oso cannot oredi lar...\n'}
# {'body': "As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there.\n"}
# {'body': 'Aight yo, dats straight dogg\n'}
# {'body': 'You please give us connection today itself before  &lt;DECIMAL&gt;  or refund the bill\n'}
# {'body': 'Both :) i shoot big loads so get ready!\n'}
# {'body': "What's up bruv, hope you had a great break. Do have a rewarding semester.\n"}
# {'body': 'Home so we can always chat\n'}
# {'body': 'K:)k:)good:)study well.\n'}
# {'body': 'Yup... How ü noe leh...\n'}
# {'body': 'Sounds great! Are you home now?\n'}
# {'body': 'Finally the match heading towards draw as your prediction.\n'}
# {'body': "Tired. I haven't slept well the past few nights.\n"}
# {'body': 'Easy ah?sen got selected means its good..\n'}
# {'body': 'I have to take exam with march 3\n'}
# {'body': "Yeah you should. I think you can use your gt atm now to register. Not sure but if there's anyway i can help let me know. But when you do be sure you are ready.\n"}
# {'body': 'Ok no prob. Take ur time.\n'}
# {'body': 'There is os called ubandu which will run without installing in hard disk...you can use that os to copy the important files in system and give it to repair shop..\n'}
# {'body': "Sorry, I'll call later\n"}
# {'body': 'U say leh... Of course nothing happen lar. Not say v romantic jus a bit only lor. I thk e nite scenery not so nice leh.\n'}
# {'body': '500 New Mobiles from 2004, MUST GO! Txt: NOKIA to No: 89545 & collect yours today!From ONLY £1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18\n'}
# {'body': 'Would really appreciate if you call me. Just need someone to talk to.\n'}
# {'body': 'Will u meet ur dream partner soon? Is ur career off 2 a flyng start? 2 find out free, txt HORO followed by ur star sign, e. g. HORO ARIES\n'}
# {'body': 'Hey company elama po mudyadhu.\n'}
# {'body': 'Life is more strict than teacher... Bcoz Teacher teaches lesson &amp; then conducts exam, But Life first conducts Exam &amp; then teaches Lessons. Happy morning. . .\n'}
# {'body': 'Dear good morning now only i am up\n'}
# {'body': 'Get down in gandhipuram and walk to cross cut road. Right side &lt;#&gt; street road and turn at first right.\n'}
# {'body': 'Dear we are going to our rubber place\n'}
# {'body': "Sorry battery died, yeah I'm here\n"}
# {'body': 'Yes:)here tv is always available in work place..\n'}
# {'body': 'Text & meet someone sexy today. U can find a date or even flirt its up to U. Join 4 just 10p. REPLY with NAME & AGE eg Sam 25. 18 -msg recd@thirtyeight pence\n'}
# {'body': 'I have printed it oh. So  &lt;#&gt;  come upstairs\n'}
# {'body': 'Or ill be a little closer like at the bus stop on the same street\n'}
# {'body': 'Where are you?when wil you reach here?\n'}
# {'body': "New Theory: Argument wins d SITUATION, but loses the PERSON. So dont argue with ur friends just.. . . . kick them &amp; say, I'm always correct.!\n"}
# {'body': 'U 447801259231 have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094597\n'}
# {'body': 'Tomarrow final hearing on my laptop case so i cant.\n'}
# {'body': 'PLEASSSSSSSEEEEEE TEL ME V AVENT DONE SPORTSx\n'}
# {'body': 'Okay. No no, just shining on. That was meant to be signing, but that sounds better.\n'}
# {'body': "Although i told u dat i'm into baig face watches now but i really like e watch u gave cos it's fr u. Thanx 4 everything dat u've done today, i'm touched...\n"}
# {'body': "U don't remember that old commercial?\n"}
# {'body': "Too late. I said i have the website. I didn't i have or dont have the slippers\n"}
# {'body': 'I asked you to call him now ok\n'}
# {'body': 'Kallis wont bat in 2nd innings.\n'}
# {'body': 'It didnt work again oh. Ok goodnight then. I.ll fix and have it ready by the time you wake up. You are very dearly missed have a good night sleep.\n'}
# {'body': 'Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16\n'}
# {'body': 'Ranjith cal drpd Deeraj and deepak 5min hold\n'}
# {'body': 'Wen ur lovable bcums angry wid u, dnt take it seriously.. Coz being angry is d most childish n true way of showing deep affection, care n luv!.. kettoda manda... Have nice day da.\n'}
# {'body': 'What you doing?how are you?\n'}
# {'body': 'Ups which is 3days also, and the shipping company that takes 2wks. The other way is usps which takes a week but when it gets to lag you may have to bribe nipost to get your stuff.\n'}
# {'body': "I'm back, lemme know when you're ready\n"}
# {'body': "Don't necessarily expect it to be done before you get back though because I'm just now headin out\n"}
# {'body': 'Mmm so yummy babe ... Nice jolt to the suzy\n'}
# {'body': 'Where are you lover ? I need you ...\n'}
# {'body': 'We tried to contact you re your reply to our offer of a Video Handset? 750 anytime networks mins? UNLIMITED TEXT? Camcorder? Reply or call 08000930705 NOW\n'}
# {'body': 'I‘m parked next to a MINI!!!! When are you coming in today do you think?\n'}
# {'body': 'Yup\n'}
# {'body': "Anyway i'm going shopping on my own now. Cos my sis not done yet. Dun disturb u liao.\n"}
# {'body': 'MY NO. IN LUTON 0125698789 RING ME IF UR AROUND! H*\n'}
# {'body': 'Hey I am really horny want to chat or see me naked text hot to 69698 text charged at 150pm to unsubscribe text stop 69698\n'}
# {'body': 'Why you Dint come with us.\n'}
# {'body': 'Same. Wana plan a trip sometme then\n'}
# {'body': 'Not sure yet, still trying to get a hold of him\n'}
# {'body': 'Ur ringtone service has changed! 25 Free credits! Go to club4mobiles.com to choose content now! Stop? txt CLUB STOP to 87070. 150p/wk Club4 PO Box1146 MK45 2WT\n'}
# {'body': 'The evo. I just had to download flash. Jealous?\n'}
# {'body': 'Ringtone Club: Get the UK singles chart on your mobile each week and choose any top quality ringtone! This message is free of charge.\n'}
# {'body': "Come to mu, we're sorting out our narcotics situation\n"}
# {'body': 'Night has ended for another day, morning has come in a special way. May you smile like the sunny rays and leaves your worries at the blue blue bay.\n'}
# {'body': 'HMV BONUS SPECIAL 500 pounds of genuine HMV vouchers to be won. Just answer 4 easy questions. Play Now! Send HMV to 86688 More info:www.100percent-real.com\n'}
# {'body': 'Usf I guess, might as well take 1 car\n'}
# {'body': 'No objection. My bf not coming.\n'}
# {'body': 'Thanx...\n'}
# {'body': 'Tell rob to mack his gf in the theater\n'}
# {'body': "Awesome, I'll see you in a bit\n"}
# {'body': 'Just sent it. So what type of food do you like?\n'}
# {'body': 'All done? All handed in? Celebrations in full swing yet?\n'}
# {'body': 'You got called a tool?\n'}
# {'body': '"Wen u miss someone, the person is definitely special for u..... But if the person is so special, why to miss them, just Keep-in-touch" gdeve..\n'}
# {'body': 'Ok. I asked for money how far\n'}
# {'body': 'Okie...\n'}
# {'body': "Yeah I think my usual guy's still passed out from last night, if you get ahold of anybody let me know and I'll throw down\n"}
# {'body': 'K, I might come by tonight then if my class lets out early\n'}
# {'body': 'Ok..\n'}
# {'body': 'hi baby im cruisin with my girl friend what r u up 2? give me a call in and hour at home if thats alright or fone me on this fone now love jenny xxx\n'}
# {'body': 'My life Means a lot to me, Not because I love my life, But because I love the people in my life, The world calls them friends, I call them my World:-).. Ge:-)..\n'}
# {'body': 'Dear,shall mail tonite.busy in the street,shall update you tonite.things are looking ok.varunnathu edukkukayee raksha ollu.but a good one in real sense.\n'}
# {'body': 'Hey you told your name to gautham ah?\n'}
# {'body': 'Haf u found him? I feel so stupid da v cam was working.\n'}
# {'body': 'Oops. 4 got that bit.\n'}
# {'body': 'Are you this much buzy\n'}
# {'body': 'I accidentally deleted the message. Resend please.\n'}
# {'body': "T-Mobile customer you may now claim your FREE CAMERA PHONE upgrade & a pay & go sim card for your loyalty. Call on 0845 021 3680.Offer ends 28thFeb.T&C's apply\n"}
# {'body': "Unless it's a situation where YOU GO GURL would be more appropriate\n"}
# {'body': 'Hurt me... Tease me... Make me cry... But in the end of my life when i die plz keep one rose on my grave and say STUPID I MISS U.. HAVE A NICE DAY BSLVYL\n'}
# {'body': 'I cant pick the phone right now. Pls send a message\n'}
# {'body': "Need a coffee run tomo?Can't believe it's that time of week already\n"}
# {'body': 'Awesome, I remember the last time we got somebody high for the first time with diesel :V\n'}
# {'body': 'Shit that is really shocking and scary, cant imagine for a second. Def up for night out. Do u think there is somewhere i could crash for night, save on taxi?\n'}
# {'body': 'Oh and by the way you do have more food in your fridge! Want to go out for a meal tonight? \n'}
# {'body': 'He is a womdarfull actor\n'}
# {'body': 'SMS. ac Blind Date 4U!: Rodds1 is 21/m from Aberdeen, United Kingdom. Check Him out http://img. sms. ac/W/icmb3cktz8r7!-4 no Blind Dates send HIDE\n'}
# {'body': 'Yup... From what i remb... I think should be can book... \n'}
# {'body': 'Jos ask if u wana meet up?\n'}
# {'body': "Lol yes. Our friendship is hanging on a thread cause u won't buy stuff.\n"}
# {'body': 'TheMob> Check out our newest selection of content, Games, Tones, Gossip, babes and sport, Keep your mobile fit and funky text WAP to 82468\n'}
# {'body': "Where are the garage keys? They aren't on the bookshelf\n"}
# {'body': 'Today is ACCEPT DAY..U Accept me as? Brother Sister Lover Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd Swtheart Bstfrnd No rply means enemy\n'}
# {'body': 'Think ur smart ? Win £200 this week in our weekly quiz, text PLAY to 85222 now!T&Cs WinnersClub PO BOX 84, M26 3UZ. 16+. GBP1.50/week\n'}
# {'body': "He says he'll give me a call when his friend's got the money but that he's definitely buying before the end of the week\n"}
# {'body': 'Hi the way I was with u 2day, is the normal way&this is the real me. UR unique&I hope I know u 4 the rest of mylife. Hope u find wot was lost.\n'}
# {'body': 'You made my day. Do have a great day too.\n'}
# {'body': 'K.k:)advance happy pongal.\n'}
# {'body': 'Hmmm... Guess we can go 4 kb n power yoga... Haha, dunno we can tahan power yoga anot... Thk got lo oso, forgot liao...\n'}
# {'body': "Not really dude, have no friends i'm afraid :(\n"}
# {'body': 'December only! Had your mobile 11mths+? You are entitled to update to the latest colour camera mobile for Free! Call The Mobile Update Co FREE on 08002986906\n'}
# {'body': 'Coffee cake, i guess...\n'}
# {'body': 'Merry Christmas to you too babe, i love ya *kisses*\n'}
# {'body': 'Hey... Why dont we just go watch x men and have lunch... Haha \n'}
# {'body': 'cud u tell ppl im gona b a bit l8 cos 2 buses hav gon past cos they were full & im still waitin 4 1. Pete x\n'}
# {'body': "That would be great. We'll be at the Guild. Could meet on Bristol road or somewhere - will get in touch over weekend. Our plans take flight! Have a good week\n"}
# {'body': 'No problem. How are you doing?\n'}
# {'body': 'No calls..messages..missed calls\n'}
# {'body': 'Hi da:)how is the todays class?\n'}
# {'body': "I'd say that's a good sign but, well, you know my track record at reading women\n"}
# {'body': "Cool, text me when you're parked\n"}
# {'body': "I'm reading the text i just sent you. Its meant to be a joke. So read it in that light\n"}
# {'body': 'K.k:)apo k.good movie.\n'}
# {'body': 'Maybe i could get book out tomo then return it immediately ..? Or something.\n'}
# {'body': 'Call Germany for only 1 pence per minute! Call from a fixed line via access number 0844 861 85 85. No prepayment. Direct access!\n'}
# {'body': "Any chance you might have had with me evaporated as soon as you violated my privacy by stealing my phone number from your employer's paperwork. Not cool at all. Please do not contact me again or I will report you to your supervisor.\n"}
# {'body': 'Valentines Day Special! Win over £1000 in our quiz and take your partner on the trip of a lifetime! Send GO to 83600 now. 150p/msg rcvd. CustCare:08718720201.\n'}
# {'body': 'Ta-Daaaaa! I am home babe, are you still up ?\n'}
# {'body': 'Cool. So how come you havent been wined and dined before?\n'}
# {'body': 'Just sleeping..and surfing\n'}
# {'body': "Sorry, I'll call later\n"}
# {'body': 'U calling me right? Call my hand phone...\n'}
# {'body': "Ok that's great thanx a lot.\n"}
# {'body': 'I take it the post has come then! You must have 1000s of texts now! Happy reading. My one from wiv hello caroline at the end is my favourite. Bless him\n'}
# {'body': 'Where u been hiding stranger?\n'}
# {'body': 'Am not interested to do like that.\n'}
# {'body': 'My sister cleared two round in birla soft yesterday.\n'}
# {'body': 'Gudnite....tc...practice going on\n'}
# {'body': 'Dis is yijue. I jus saw ur mail. In case huiming havent sent u my num. Dis is my num.\n'}
# {'body': 'One small prestige problem now.\n'}
# {'body': 'Fancy a shag? I do.Interested? sextextuk.com txt XXUK SUZY to 69876. Txts cost 1.50 per msg. TnCs on website. X\n'}
# {'body': 'Just checking in on you. Really do miss seeing Jeremiah. Do have a great month\n'}
# {'body': "Nah can't help you there, I've never had an iphone\n"}
# {'body': "If you're not in my car in an hour and a half I'm going apeshit\n"}
# {'body': "TODAY is Sorry day.! If ever i was angry with you, if ever i misbehaved or hurt you? plz plz JUST SLAP URSELF Bcoz, Its ur fault, I'm basically GOOD\n"}
# {'body': 'Yo you guys ever figure out how much we need for alcohol? Jay and I are trying to figure out how much we can safely spend on weed\n'}
# {'body': '&lt;#&gt; ISH MINUTES WAS 5 MINUTES AGO. WTF.\n'}
# {'body': 'Thank You for calling.Forgot to say Happy Onam to you Sirji.I am fine here and remembered you when i met an insurance person.Meet You in Qatar Insha Allah.Rakhesh, ex Tata AIG who joined TISSCO,Tayseer.\n'}
# {'body': 'Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16\n'}
# {'body': 'Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send CASH to 86688 only 150p/msg. CC: 08708800282 HG/Suite342/2Lands Row/W1J6HL\n'}
# {'body': "I'm an actor. When i work, i work in the evening and sleep late. Since i'm unemployed at the moment, i ALWAYS sleep late. When you're unemployed, every day is saturday.\n"}
# {'body': 'Hello! Just got here, st andrews-boy its a long way! Its cold. I will keep you posted\n'}
# {'body': 'Ha ha cool cool chikku chikku:-):-DB-)\n'}
# {'body': 'Oh ok no prob..\n'}
# {'body': "Check audrey's status right now\n"}
# {'body': 'Busy here. Trying to finish for new year. I am looking forward to finally meeting you...\n'}
# {'body': 'Good afternoon sunshine! How dawns that day ? Are we refreshed and happy to be alive? Do we breathe in the air and smile ? I think of you, my love ... As always\n'}
# {'body': 'Well i know Z will take care of me. So no worries.\n'}
# {'body': 'Update_Now - Xmas Offer! Latest Motorola, SonyEricsson & Nokia & FREE Bluetooth! Double Mins & 1000 Txt on Orange. Call MobileUpd8 on 08000839402 or call2optout/F4Q=\n'}
# {'body': 'Here is your discount code RP176781. To stop further messages reply stop. www.regalportfolio.co.uk. Customer Services 08717205546\n'}
# {'body': 'Wat uniform? In where get?\n'}
# {'body': "Cool, text me when you're ready\n"}
# {'body': 'Hello my boytoy ... Geeee I miss you already and I just woke up. I wish you were here in bed with me, cuddling me. I love you ...\n'}
# {'body': 'I will spoil you in bed as well :)\n'}
# {'body': "I'm going for bath will msg you next  &lt;#&gt;  min..\n"}
# {'body': 'I cant keep talking to people if am not sure i can pay them if they agree to price. So pls tell me what you want to really buy and how much you are willing to pay\n'}
# {'body': 'Thanks for your Ringtone Order, Reference T91. You will be charged GBP 4 per week. You can unsubscribe at anytime by calling customer services on 09057039994\n'}
# {'body': 'Can you say what happen\n'}
# {'body': "You could have seen me..i did't recognise you Face.:)\n"}
# {'body': "Well there's not a lot of things happening in Lindsay on New years *sighs* Some bars in Ptbo and the blue heron has something going\n"}
# {'body': 'Keep my payasam there if rinu brings\n'}
# {'body': 'I taught that Ranjith sir called me. So only i sms like that. Becaus hes verifying about project. Prabu told today so only pa dont mistake me..\n'}
# {'body': "I guess that's why you re worried. You must know that there's a way the body repairs itself. And i'm quite sure you shouldn't worry. We'll take it slow. First the tests, they will guide when your ovulation is then just relax. Nothing you've said is a reason to worry but i.ll keep on followin you up.\n"}
# {'body': 'Yeah sure, give me a couple minutes to track down my wallet\n'}
# {'body': 'Hey leave it. not a big deal:-) take care.\n'}
# {'body': 'Hey i will be late ah... Meet you at 945+\n'}
# {'body': 'Double mins and txts 4 6months FREE Bluetooth on Orange. Available on Sony, Nokia Motorola phones. Call MobileUpd8 on 08000839402 or call2optout/N9DX\n'}
# {'body': 'It took Mr owl 3 licks\n'}
# {'body': 'Customer place i will call you.\n'}
# {'body': 'Mm that time you dont like fun\n'}
# {'body': '4mths half price Orange line rental & latest camera phones 4 FREE. Had your phone 11mths ? Call MobilesDirect free on 08000938767 to update now! or2stoptxt\n'}
# {'body': 'Yup having my lunch buffet now.. U eat already?\n'}
# {'body': 'Huh so late... Fr dinner?\n'}
# {'body': 'Hey so this sat are we going for the intro pilates only? Or the kickboxing too? \n'}
# {'body': 'Morning only i can ok.\n'}
# {'body': 'Yes i think so. I am in office but my lap is in room i think thats on for the last few days. I didnt shut that down\n'}
# {'body': 'Pick you up bout 7.30ish? What time are  and that going?\n'}
# {'body': 'From here after The performance award is calculated every two month.not for current one month period..\n'}
# {'body': 'Was actually sleeping and still might when u call back. So a text is gr8. You rock sis. Will send u a text wen i wake.\n'}
# {'body': "You are always putting your business out there. You put pictures of your ass on facebook. You are one of the most open people i've ever met. Why would i think a picture of your room would hurt you, make you feel violated.\n"}
# {'body': 'Good evening Sir, Al Salam Wahleykkum.sharing a happy news.By the grace of God, i got an offer from Tayseer,TISSCO and i joined.Hope you are fine.Inshah Allah,meet you sometime.Rakhesh,visitor from India.\n'}
# {'body': 'Hmmm...k...but i want to change the field quickly da:-)i wanna get system administrator or network administrator..\n'}
# {'body': 'FREE RINGTONE text FIRST to 87131 for a poly or text GET to 87131 for a true tone! Help? 0845 2814032 16 after 1st free, tones are 3x£150pw to e£nd txt stop\n'}
# {'body': 'Dear how is chechi. Did you talk to her\n'}
# {'body': 'The hair cream has not been shipped.\n'}
# {'body': "None of that's happening til you get here though\n"}
# {'body': 'Yep, the great loxahatchee xmas tree burning of  &lt;#&gt;  starts in an hour\n'}
# {'body': 'Haha get used to driving to usf man, I know a lot of stoners\n'}
# {'body': "All was well until slightly disastrous class this pm with my fav darlings! Hope day off ok. Coffee wld be good as can't stay late tomorrow. Same time + place as always?\n"}
# {'body': 'Hello! Good week? Fancy a drink or something later?\n'}
# {'body': 'Headin towards busetop\n'}
# {'body': 'Message:some text missing* Sender:Name Missing* *Number Missing *Sent:Date missing *Missing U a lot thats y everything is missing sent via fullonsms.com\n'}
# {'body': 'Come by our room at some point so we can iron out the plan for this weekend\n'}
# {'body': 'Cos i want it to be your thing\n'}
# {'body': "Okies... I'll go yan jiu too... We can skip ard oso, go cine den go mrt one, blah blah blah... \n"}
# {'body': 'Bring home some Wendy =D\n'}
# {'body': '100 dating service cal;l 09064012103 box334sk38ch\n'}
# {'body': 'Whatsup there. Dont u want to sleep\n'}
# {'body': 'Alright i have a new goal now\n'}
# {'body': 'FREE entry into our £250 weekly competition just text the word WIN to 80086 NOW. 18 T&C www.txttowin.co.uk\n'}
# {'body': "Alright, I'll head out in a few minutes, text me where to meet you\n"}
# {'body': 'Send a logo 2 ur lover - 2 names joined by a heart. Txt LOVE NAME1 NAME2 MOBNO eg LOVE ADAM EVE 07123456789 to 87077 Yahoo! POBox36504W45WQ TxtNO 4 no ads 150p\n'}
# {'body': "Yes:)from last week itself i'm taking live call.\n"}
# {'body': 'Someone has contacted our dating service and entered your phone because they fancy you! To find out who it is call from a landline 09111032124 . PoBox12n146tf150p\n'}
# {'body': 'Siva is in hostel aha:-.\n'}
# {'body': 'URGENT! Your Mobile number has been awarded with a £2000 prize GUARANTEED. Call 09058094455 from land line. Claim 3030. Valid 12hrs only\n'}
# {'body': 'Send this to ur friends and receive something about ur voice..... How is my speaking expression? 1.childish 2.naughty 3.Sentiment 4.rowdy 5.ful of attitude 6.romantic 7.shy 8.Attractive 9.funny  &lt;#&gt; .irritating  &lt;#&gt; .lovable. reply me..\n'}
# {'body': "Ok. She'll be ok. I guess\n"}
# {'body': 'aathi..where are you dear..\n'}
# {'body': 'Any pain on urination any thing else?\n'}
# {'body': '7 at esplanade.. Do ü mind giving me a lift cos i got no car today..\n'}
# {'body': 'I wnt to buy a BMW car urgently..its vry urgent.but hv a shortage of  &lt;#&gt; Lacs.there is no source to arng dis amt. &lt;#&gt; lacs..thats my prob\n'}
# {'body': 'At home watching tv lor.\n'}
# {'body': 'Does she usually take fifteen fucking minutes to respond to a yes or no question\n'}
# {'body': 'Congrats! Nokia 3650 video camera phone is your Call 09066382422 Calls cost 150ppm Ave call 3mins vary from mobiles 16+ Close 300603 post BCM4284 Ldn WC1N3XX\n'}
# {'body': 'Booked ticket for pongal?\n'}
# {'body': "You available now? I'm like right around hillsborough &amp;  &lt;#&gt; th\n"}
# {'body': 'The message sent is askin for  &lt;#&gt; dollars. Shoul i pay  &lt;#&gt;  or  &lt;#&gt; ?\n'}
# {'body': "Ask g or iouri, I've told the story like ten times already\n"}
# {'body': 'How long does applebees fucking take\n'}
# {'body': 'Hi hope u get this txt~journey hasnt been gd,now about 50 mins late I think.\n'}
# {'body': 'But i have to. I like to have love and arrange.\n'}
# {'body': 'Yes..he is really great..bhaji told kallis best cricketer after sachin in world:).very tough to get out.\n'}
# {'body': 'You were supposed to wake ME up &gt;:(\n'}
# {'body': 'Oic... I saw him too but i tot he din c me... I found a group liao...\n'}
# {'body': "Sorry, I'll call later\n"}
# {'body': '"HEY HEY WERETHE MONKEESPEOPLE SAY WE MONKEYAROUND! HOWDY GORGEOUS, HOWU DOIN? FOUNDURSELF A JOBYET SAUSAGE?LOVE JEN XXX"\n'}
# {'body': "Sorry, my battery died, I can come by but I'm only getting a gram for now, where's your place?\n"}
# {'body': 'Well done, blimey, exercise, yeah, i kinda remember wot that is, hmm. \n'}
# {'body': 'I wont get concentration dear you know you are my mind and everything :-)\n'}
# {'body': 'LOL ... Have you made plans for new years?\n'}
# {'body': '10 min later k...\n'}
# {'body': 'hanks lotsly!\n'}
# {'body': 'Thanks for this hope you had a good day today\n'}
# {'body': 'K:)k:)what are detail you want to transfer?acc no enough?\n'}
# {'body': 'Ok i will tell her to stay out. Yeah its been tough but we are optimistic things will improve this month.\n'}
# {'body': "Loan for any purpose £500 - £75,000. Homeowners + Tenants welcome. Have you been previously refused? We can still help. Call Free 0800 1956669 or text back 'help'\n"}
# {'body': 'Si si. I think ill go make those oreo truffles.\n'}
# {'body': 'LOOK AT AMY URE A BEAUTIFUL, INTELLIGENT WOMAN AND I LIKE U A LOT. I KNOW U DON\x92T LIKE ME LIKE THAT SO DON\x92T WORRY.\n'}
# {'body': "I hope you that's the result of being consistently intelligent and kind. Start asking him about practicum links and keep your ears open and all the best. ttyl\n"}
# {'body': '1.20 that call cost. Which i guess isnt bad. Miss ya, need ya, want ya, love ya\n'}
# {'body': 'Going thru a very different feeling.wavering decisions and coping up with the same is the same individual.time will heal everything i believe.\n'}
# {'body': 'Where did u go? My phone is gonna die you have to stay in here\n'}
# {'body': 'Great. Never been better. Each day gives even more reasons to thank God\n'}
# {'body': "UpgrdCentre Orange customer, you may now claim your FREE CAMERA PHONE upgrade for your loyalty. Call now on 0207 153 9153. Offer ends 26th July. T&C's apply. Opt-out available\n"}
# {'body': "Sorry, I'll call later ok bye\n"}
# {'body': 'Ok i am on the way to railway\n'}
# {'body': 'great princess! I love giving and receiving oral. Doggy style is my fave position. How about you? I enjoy making love  &lt;#&gt;  times per night :)\n'}
# {'body': "They don't put that stuff on the roads to keep it from getting slippery over there?\n"}
# {'body': 'When are you going to ride your bike?\n'}
# {'body': "Yup, no need. I'll jus wait 4 e rain 2 stop.\n"}
# {'body': 'There are many company. Tell me the language.\n'}
# {'body': 'okmail: Dear Dave this is your final notice to collect your 4* Tenerife Holiday or #5000 CASH award! Call 09061743806 from landline. TCs SAE Box326 CW25WX 150ppm\n'}
# {'body': 'How long has it been since you screamed, princess?\n'}
# {'body': 'Nothing. I meant that once the money enters your account here, the bank will remove its flat rate. Someone transfered  &lt;#&gt;  to my account and  &lt;#&gt; dollars got removed. So the banks differ and charges also differ.be sure you trust the 9ja person you are sending account details to cos...\n'}
# {'body': "Want 2 get laid tonight? Want real Dogging locations sent direct 2 ur Mob? Join the UK's largest Dogging Network by txting MOAN to 69888Nyt. ec2a. 31p.msg@150p\n"}
# {'body': "Nice line said by a broken heart- Plz don't cum 1 more times infront of me... Other wise once again I ll trust U... Good 9t:)\n"}
# {'body': "Ok I'm gonna head up to usf in like fifteen minutes\n"}
# {'body': 'Love you aathi..love u lot..\n'}
# {'body': 'Tension ah?what machi?any problem?\n'}
# {'body': "K, can I pick up another 8th when you're done?\n"}
# {'body': "When're you guys getting back? G said you were thinking about not staying for mcr\n"}
# {'body': 'Almost there, see u in a sec\n'}
# {'body': 'Yo carlos, a few friends are already asking me about you, you working at all this weekend?\n'}
# {'body': 'Watching tv lor...\n'}
# {'body': 'Thank you baby! I cant wait to taste the real thing...\n'}
# {'body': 'You should change your fb to jaykwon thuglyfe falconerf\n'}
# {'body': 'If we win its really no 1 side for long time.\n'}
# {'body': 'FREE MESSAGE Activate your 500 FREE Text Messages by replying to this message with the word FREE For terms & conditions, visit www.07781482378.com\n'}
# {'body': 'Dear reached railway. What happen to you\n'}
# ...
# {'body': 'Dunno lei shd b driving lor cos i go sch 1 hr oni.\n'}
# {'body': 'As in i want custom officer discount oh.\n'}
# {'body': "That's necessarily respectful\n"}
# {'body': 'Hi. Hope you had a good day. Have a better night.\n'}
# {'body': "And he's apparently bffs with carly quick now\n"}
# {'body': 'HARD BUT TRUE: How much you show &amp;  express your love to someone....that much it will hurt when they leave you or you get seperated...!鈥┾??〨ud evening...\n'}
# {'body': 'Babes I think I got ur brolly I left it in English wil bring it in 2mrw 4 u luv Franxx\n'}
# {'body': 'Hi babe its me thanks for coming even though it didnt go that well!i just wanted my bed! Hope to see you soon love and kisses xxx\n'}
# {'body': 'So gd got free ice cream... I oso wan...\n'}
# {'body': 'Pls give her prometazine syrup. 5mls then  &lt;#&gt; mins later feed.\n'}
# {'body': 'So how many days since then?\n'}
# {'body': 'Dear are you angry i was busy dear\n'}
# {'body': "Yup he msg me: is tat yijue? Then i tot it's my group mate cos we meeting today mah... I'm askin if ü leaving earlier or wat mah cos mayb ü haf to walk v far...\n"}
# {'body': '... Are you in the pub?\n'}
# {'body': 'There is a first time for everything :)\n'}
# {'body': "Daddy, shu shu is looking 4 u... U wan me 2 tell him u're not in singapore or wat?\n"}
# {'body': 'I ask if u meeting da ge tmr nite...\n'}
# {'body': "Gr8. So how do you handle the victoria island traffic. Plus when's the album due\n"}
# {'body': 'Nite nite pocay wocay luv u more than n e thing 4eva I promise ring u 2morrowxxxx\n'}
# {'body': 'East coast\n'}
# {'body': "You should get more chicken broth if you want ramen unless there's some I don't know about\n"}
# {'body': 'My slave! I want you to take 2 or 3 pictures of yourself today in bright light on your cell phone! Bright light!\n'}
# {'body': 'Nope. I just forgot. Will show next week\n'}
# {'body': "So how are you really. What are you up to. How's the masters. And so on.\n"}
# {'body': "I'm at bruce &amp; fowler now but I'm in my mom's car so I can't park (long story)\n"}
# {'body': 'I dont know oh. Hopefully this month.\n'}
# {'body': "Hi elaine, is today's meeting confirmed?\n"}
# {'body': 'Ok k..sry i knw 2 siva..tats y i askd..\n'}
# {'body': "Sorry, I'll call later\n"}
# {'body': 'U horrible gal... U knew dat i was going out wif him yest n u still come n ask me...\n'}
# {'body': 'Otherwise had part time job na-tuition..\n'}
# {'body': 'Oh yeah! And my diet just flew out the window\n'}
# {'body': 'Santa Calling! Would your little ones like a call from Santa Xmas eve? Call 09058094583 to book your time.\n'}
# {'body': 'You didnt complete your gist oh.\n'}
# {'body': 'Er yeah, i will b there at 15:26, sorry! Just tell me which pub/cafe to sit in and come wen u can\n'}
# {'body': "If you can make it any time tonight or whenever you can it's cool, just text me whenever you're around\n"}
# {'body': "If I was I wasn't paying attention\n"}
# {'body': 'Thanx a lot 4 ur help!\n'}
# {'body': "You're gonna have to be way more specific than that\n"}
# {'body': 'Jesus armand really is trying to tell everybody he can find\n'}
# {'body': "I'm wif him now buying tix lar...\n"}
# {'body': 'Mode men or have you left.\n'}
# {'body': "Am slow in using biola's fne\n"}
# {'body': '"What are youdoing later? Sar xxx"\n'}
# {'body': "Hey i've booked the 2 lessons on sun liao...\n"}
# {'body': 'Thank you. do you generally date the brothas?\n'}
# {'body': 'By the way, make sure u get train to worc foregate street not shrub hill. Have fun night x\n'}
# {'body': "I thought i'd get him a watch, just cos thats the kind of thing u get4an18th. And he loves so much!\n"}
# {'body': 'You have won a guaranteed 32000 award or maybe even £1000 cash to claim ur award call free on 0800 ..... (18+). Its a legitimat efreefone number wat do u think???\n'}
# {'body': "Good morning. At the repair shop--the ONLY reason i'm up at this hour.\n"}
# {'body': "And that's fine, I got enough bud to last most of the night at least\n"}
# {'body': 'I am back. Good journey! Let me know if you need any of the receipts. Shall i tell you like the pendent?\n'}
# {'body': 'So that takes away some money worries\n'}
# {'body': 'aight we can pick some up, you open before tonight?\n'}
# {'body': 'Latest News! Police station toilet stolen, cops have nothing to go on!\n'}
# {'body': 'Sac needs to carry on:)\n'}
# {'body': 'Just sing HU. I think its also important to find someone female that know the place well preferably a citizen that is also smart to help you navigate through. Even things like choosing a phone plan require guidance. When in doubt ask especially girls.\n'}
# {'body': 'What???? Hello wats talks email address?\n'}
# {'body': 'Except theres a chick with huge boobs.\n'}
# {'body': 'Im just wondering what your doing right now?\n'}
# {'body': 'Wishing you a beautiful day. Each moment revealing even more things to keep you smiling. Do enjoy it.\n'}
# {'body': '"For the most sparkling shopping breaks from 45 per person; call 0121 2025050 or visit www.shortbreaks.org.uk"\n'}
# {'body': 'Arun can u transfr me d amt\n'}
# {'body': "Sorry, I'll call later\n"}
# {'body': "If you hear a loud scream in about &lt;#&gt; minutes its cause my Gyno will be shoving things up me that don't belong :/\n"}
# {'body': 'December only! Had your mobile 11mths+? You are entitled to update to the latest colour camera mobile for Free! Call The Mobile Update Co FREE on 08002986906\n'}
# {'body': 'Ok i thk i got it. Then u wan me 2 come now or wat?\n'}
# {'body': 'Txt: CALL to No: 86888 & claim your reward of 3 hours talk time to use from your phone now! Subscribe6GBP/mnth inc 3hrs 16 stop?txtStop www.gamb.tv\n'}
# {'body': 'U GOIN OUT 2NITE?\n'}
# {'body': 'I will treasure every moment we spend together...\n'}
# {'body': 'Shall I bring us a bottle of wine to keep us amused? Only joking! I‘ll bring one anyway\n'}
# {'body': 'http//tms. widelive.com/index. wml?id=820554ad0a1705572711&first=true¡C C Ringtone¡\n'}
# {'body': 'Get your garden ready for summer with a FREE selection of summer bulbs and seeds worth £33:50 only with The Scotsman this Saturday. To stop go2 notxt.co.uk\n'}
# {'body': "URGENT! Last weekend's draw shows that you have won £1000 cash or a Spanish holiday! CALL NOW 09050000332 to claim. T&C: RSTM, SW7 3SS. 150ppm\n"}
# {'body': 'Ok lor.\n'}
# {'body': 'I thought slide is enough.\n'}
# {'body': 'Yup\n'}
# {'body': 'Well obviously not because all the people in my cool college life went home ;_;\n'}
# {'body': 'Ok lor ü reaching then message me.\n'}
# {'body': "Where's mummy's boy ? Is he being good or bad ? Is he being positive or negative ? Why is mummy being made to wait? Hmmmm?\n"}
# {'body': 'Dhoni have luck to win some big title.so we will win:)\n'}
# {'body': 'Yes princess! I want to please you every night. Your wish is my command...\n'}
# {'body': 'What Today-sunday..sunday is holiday..so no work..\n'}
# {'body': 'No probably  &lt;#&gt; %.\n'}
# {'body': 'Really do hope the work doesnt get stressful. Have a gr8 day.\n'}
# {'body': "Have you seen who's back at Holby?!\n"}
# {'body': 'Shall call now dear having food\n'}
# {'body': 'URGENT We are trying to contact you Last weekends draw shows u have won a £1000 prize GUARANTEED Call 09064017295 Claim code K52 Valid 12hrs 150p pm\n'}
# {'body': 'So li hai... Me bored now da lecturer repeating last weeks stuff waste time... \n'}
# {'body': ', ,  and  picking them up from various points | going 2 yeovil | and they will do the motor project 4 3 hours | and then u take them home. || 12 2 5.30 max. || Very easy\n'}
# {'body': 'Also fuck you and your family for going to rhode island or wherever the fuck and leaving me all alone the week I have a new bong &gt;:(\n'}
# {'body': 'Ofcourse I also upload some songs\n'}
# {'body': "2p per min to call Germany 08448350055 from your BT line. Just 2p per min. Check PlanetTalkInstant.com for info & T's & C's. Text stop to opt out\n"}
# {'body': 'K. I will sent it again\n'}
# {'body': 'Oh thanks a lot..i already bought 2 eggs ..\n'}
# {'body': 'K. I will sent it again\n'}
# {'body': "U studying in sch or going home? Anyway i'll b going 2 sch later.\n"}
# {'body': 'Marvel Mobile Play the official Ultimate Spider-man game (£4.50) on ur mobile right now. Text SPIDER to 83338 for the game & we ll send u a FREE 8Ball wallpaper\n'}
# {'body': 'I think if he rule tamilnadu..then its very tough for our people.\n'}
# {'body': 'Cool, we shall go and see, have to go to tip anyway. Are you at home, got something to drop in later? So lets go to town tonight! Maybe mum can take us in.\n'}
# {'body': 'Good afternoon, my love ... How goes your day ? How did you sleep ? I hope your well, my boytoy ... I think of you ...\n'}
# {'body': 'Yes... I trust u to buy new stuff ASAP so I can try it out\n'}
# {'body': 'SMS SERVICES. for your inclusive text credits, pls goto www.comuk.net login= 3qxj9 unsubscribe with STOP, no extra charge. help 08702840625.COMUK. 220-CM2 9AE\n'}
# {'body': 'Why did I wake up on my own &gt;:(\n'}
# {'body': 'Now get step 2 outta the way. Congrats again.\n'}
# {'body': 'Love has one law; Make happy the person you love. In the same way friendship has one law; Never make ur friend feel alone until you are alive.... Gud night\n'}
# {'body': 'PRIVATE! Your 2003 Account Statement for 07808247860 shows 800 un-redeemed S. I. M. points. Call 08719899229 Identifier Code: 40411 Expires 06/11/04\n'}
# {'body': 'Apo all other are mokka players only\n'}
# {'body': 'Perhaps * is much easy give your account identification, so i will tomorrow at UNI\n'}
# {'body': 'Wait . I will msg after  &lt;#&gt;  min.\n'}
# {'body': 'What i told before i tell. Stupid hear after i wont tell anything to you. You dad called to my brother and spoken. Not with me.\n'}
# {'body': "God's love has no limit. God's grace has no measure. God's power has no boundaries. May u have God's endless blessings always in ur life...!! Gud ni8\n"}
# {'body': 'I want to be inside you every night...\n'}
# {'body': 'Machan you go to gym tomorrow,  i wil come late goodnight.\n'}
# {'body': 'Lol they were mad at first but then they woke up and gave in.\n'}
# {'body': 'I went to project centre\n'}
# {'body': 'It‘s reassuring, in this crazy world.\n'}
# {'body': 'Just making dinner, you ?\n'}
# {'body': 'Yes. Please leave at  &lt;#&gt; . So that at  &lt;#&gt;  we can leave\n'}
# {'body': 'Oh... Okie lor...We go on sat... \n'}
# {'body': "You are a great role model. You are giving so much and i really wish each day for a miracle but God as a reason for everything and i must say i wish i knew why but i dont. I've looked up to you since i was young and i still do. Have a great day.\n"}
# {'body': "Ya, i'm referin to mei's ex wat... No ah, waitin 4 u to treat, somebody shld b rich liao...So gd, den u dun have to work frm tmr onwards...\n"}
# {'body': 'Miles and smiles r made frm same letters but do u know d difference..? smile on ur face keeps me happy even though I am miles away from u.. :-)keep smiling.. Good nyt\n'}
# {'body': "By the way, i've put a skip right outside the front of the house so you can see which house it is. Just pull up before it.\n"}
# {'body': 'Can you pls send me that company name. In saibaba colany\n'}
# {'body': 'No. I dont want to hear anything\n'}
# {'body': 'You are a big chic. Common. Declare\n'}
# {'body': 'Thats cool. I want to please you...\n'}
# {'body': 'Going to join tomorrow.\n'}
# {'body': 'You are awarded a SiPix Digital Camera! call 09061221061 from landline. Delivery within 28days. T Cs Box177. M221BP. 2yr warranty. 150ppm. 16 . p p£3.99\n'}
# {'body': 'I want to tell you how bad I feel that basically the only times I text you lately are when I need drugs\n'}
# {'body': 'PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S.I.M. points. Call 08718738001 Identifier Code: 49557 Expires 26/11/04\n'}
# {'body': 'Total disappointment, when I texted you was the craziest shit got :(\n'}
# {'body': 'Its just the effect of irritation. Just ignore it\n'}
# {'body': 'What about this one then.\n'}
# {'body': "I think that tantrum's finished so yeah I'll be by at some point\n"}
# {'body': 'Compliments to you. Was away from the system. How your side.\n'}
# {'body': 'happened here while you were adventuring\n'}
# {'body': 'Hey chief, can you give me a bell when you get this. Need to talk to you about this royal visit on the 1st june. \n'}
# {'body': 'Ok which your another number\n'}
# {'body': 'I know you are thinkin malaria. But relax, children cant handle malaria. She would have been worse and its gastroenteritis. If she takes enough to replace her loss her temp will reduce. And if you give her malaria meds now she will just vomit. Its a self limiting illness she has which means in a few days it will completely stop\n'}
# {'body': 'Aiyah ok wat as long as got improve can already wat...\n'}
# {'body': 'Want explicit SEX in 30 secs? Ring 02073162414 now! Costs 20p/min Gsex POBOX 2667 WC1N 3XX\n'}
# {'body': "I can't believe how attached I am to seeing you every day. I know you will do the best you can to get to me babe. I will go to teach my class at your midnight\n"}
# {'body': 'Just sleeping..and surfing\n'}
# {'body': 'ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE MINS. INDIA CUST SERVs SED YES. L8ER GOT MEGA BILL. 3 DONT GIV A SHIT. BAILIFF DUE IN DAYS. I O £250 3 WANT £800\n'}
# {'body': "Yeah it's jus rite...\n"}
# {'body': 'Armand says get your ass over to epsilon\n'}
# {'body': 'U still havent got urself a jacket ah?\n'}
# {'body': "I'm taking derek &amp; taylor to walmart, if I'm not back by the time you're done just leave the mouse on my desk and I'll text you when priscilla's ready\n"}
# {'body': 'Hi its in durban are you still on this number\n'}
# {'body': 'Ic. There are a lotta childporn cars then.\n'}
# {'body': 'Had your contract mobile 11 Mnths? Latest Motorola, Nokia etc. all FREE! Double Mins & Text on Orange tariffs. TEXT YES for callback, no to remove from records.\n'}
# {'body': 'No, I was trying it all weekend ;V\n'}
# {'body': 'You know, wot people wear. T shirts, jumpers, hat, belt, is all we know. We r at Cribbs\n'}
# {'body': 'Cool, what time you think you can get here?\n'}
# {'body': "Wen did you get so spiritual and deep. That's great\n"}
# {'body': 'Have a safe trip to Nigeria. Wish you happiness and very soon company to share moments with\n'}
# {'body': 'Hahaha..use your brain dear\n'}
# {'body': "Well keep in mind I've only got enough gas for one more round trip barring a sudden influx of cash\n"}
# {'body': 'Yeh. Indians was nice. Tho it did kane me off a bit he he. We shud go out 4 a drink sometime soon. Mite hav 2 go 2 da works 4 a laugh soon. Love Pete x x\n'}
# {'body': "Yes i have. So that's why u texted. Pshew...missing you so much\n"}
# {'body': "No. I meant the calculation is the same. That  &lt;#&gt; units at  &lt;#&gt; . This school is really expensive. Have you started practicing your accent. Because its important. And have you decided if you are doing 4years of dental school or if you'll just do the nmde exam.\n"}
# {'body': "Sorry, I'll call later\n"}
# {'body': "if you aren't here in the next  &lt;#&gt;  hours imma flip my shit\n"}
# {'body': 'Anything lor. Juz both of us lor.\n'}
# {'body': 'Get me out of this dump heap. My mom decided to come to lowes. BORING.\n'}
# {'body': 'Ok lor... Sony ericsson salesman... I ask shuhui then she say quite gd 2 use so i considering...\n'}
# {'body': 'Ard 6 like dat lor.\n'}
# {'body': "Why don't you wait 'til at least wednesday to see if you get your .\n"}
# {'body': 'Huh y lei...\n'}
# {'body': 'REMINDER FROM O2: To get 2.50 pounds free call credit and details of great offers pls reply 2 this text with your valid name, house no and postcode\n'}
# {'body': 'This is the 2nd time we have tried 2 contact u. U have won the £750 Pound prize. 2 claim is easy, call 087187272008 NOW1! Only 10p per minute. BT-national-rate.\n'}
# {'body': 'Will ü b going to esplanade fr home?\n'}
# {'body': 'Pity, * was in mood for that. So...any other suggestions?\n'}
# {'body': "The guy did some bitching but I acted like i'd be interested in buying something else next week and he gave it to us for free\n"}
# {'body': 'Rofl. Its true to its name\n'}

# %% [markdown]
# This is well summarized in the following schema from [Online Active Learning Methods for Fast Label-Efficient Spam Filtering](https://citeseerx.ist.psu.edu/document?repid=rep1&type=pdf&doi=6fef6272cd72292e2f5a54d02d6e5352664e20cb).

# %% [markdown]
# <div align="center">
#     <img width="50%" src="../img/online_active_learning.png" />
# </div>

# %%
from river import linear_model

model = linear_model.LogisticRegression()
model
# Out:
# LogisticRegression (
#   optimizer=SGD (
#     lr=Constant (
#       learning_rate=0.01
#     )
#   )
#   loss=Log (
#     weight_pos=1.
#     weight_neg=1.
#   )
#   l2=0.
#   l1=0.
#   intercept_init=0.
#   intercept_lr=Constant (
#     learning_rate=0.01
#   )
#   clip_gradient=1e+12
#   initializer=Zeros ()
# )

# %% [markdown]
# ## Reduce training time

# %% [markdown]
# #

# %% [markdown]
# ## Production considerations
